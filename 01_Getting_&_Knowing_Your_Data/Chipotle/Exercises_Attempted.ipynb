# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
#help(chipo.head)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
#print(len(chipo))
print(help(chipo.groupby(by=chipo['item_name'])))
# Out:
# Help on DataFrameGroupBy in module pandas.core.groupby.groupby object:
#
# class DataFrameGroupBy(NDFrameGroupBy)
#  |  Class for grouping and aggregating relational data. See aggregate,
#  |  transform, and apply functions on this object.
#  |
#  |  It's easiest to use obj.groupby(...) to use GroupBy, but you can also do:
#  |
#  |  ::
#  |
#  |      grouped = groupby(obj, ...)
#  |
#  |  Parameters
#  |  ----------
#  |  obj : pandas object
#  |  axis : int, default 0
#  |  level : int, default None
#  |      Level of MultiIndex
#  |  groupings : list of Grouping objects
#  |      Most users should ignore this
#  |  exclusions : array-like, optional
#  |      List of columns to exclude
#  |  name : string
#  |      Most users should ignore this
#  |
#  |  Notes
#  |  -----
#  |  After grouping, see aggregate, apply, and transform functions. Here are
#  |  some other brief notes about usage. When grouping by multiple groups, the
# ...

# %%
# Solution 2
print(chipo.shape) #Returns no. of rows and columns of the underlying numpy array
# Out:
# (4622, 5)

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
cols = chipo.shape[1]
print(cols)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
print(chipo.index) #This is the default index that a DataFrame or a Series has if no index parameter was passed when creating the DF/Series
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
#help(pd.concat)

'''items = pd.concat([chipo['quantity'],chipo['item_name']],axis = 1) #axis argument specifies which axis to concatenate along
#print(type(items.values)) A numpy array
item_count = {}
for item in item_name.values:
    if item not in item_count.keys():
        item_count[item] = 1
    else:
        item_count[item] += 1
'''
#print(dir(chipo.groupby(['item_name'])))
#iterator = iter(chipo.groupby(['item_name']))
#for item in iterator:
    #print(item)
chipo.groupby(['item_name'])['quantity'].agg(sum).nlargest(1).index[0]
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo.groupby(['item_name'])['quantity'].agg(sum).nlargest(1)[0]
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.groupby(['choice_description'])['quantity'].agg(sum).nlargest(1).index[0]
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %% [markdown]
# #### Step 13.c. Check the item price type

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
# ### Step 17. How many different items are sold?
